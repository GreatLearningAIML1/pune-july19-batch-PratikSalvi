# %% [markdown]
# ## Linear Classifier in TensorFlow
# Using Low Level API in Eager Execution mode

# %% [markdown]
# ### Load tensorflow

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
#Enable Eager Execution if using tensflow version < 2.0
#From tensorflow v2.0 onwards, Eager Execution will be enabled by default
#tf.enable_eager_execution()

# %% [markdown]
# ### Collect Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/My Drive/Great Learning/Residency 6/Day 2/Internal lab/prices.csv')

# %% [markdown]
# ### Check all columns in the dataset

# %%
data.columns
# Out:
# Index([u'date', u'symbol', u'open', u'close', u'low', u'high', u'volume'], dtype='object')

# %%
data.head()
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
# date      851264 non-null object
# symbol    851264 non-null object
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %% [markdown]
# ### Drop columns `date` and  `symbol`

# %%
data.drop(['date','symbol'],axis=1,inplace=True)

# %%
data.head()
# Out:
#          open       close         low        high     volume
# 0  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  117.010002  114.970001  114.089996  117.330002  1408600.0

# %%
data.shape
# Out:
# (851264, 5)

# %% [markdown]
# ### Consider only first 1000 rows in the dataset for building feature set and target set
# Target 'Volume' has very high values. Divide 'Volume' by 1000,000

# %%
# split into input (X) and output (Y) variables
X = data.iloc[0:1000,0:4]
Y = data.iloc[0:1000,4]

# %%
X.head()
# Out:
#          open       close         low        high
# 0  123.430000  125.839996  122.309998  126.250000
# 1  125.239998  119.980003  119.940002  125.540001
# 2  116.379997  114.949997  114.930000  119.739998
# 3  115.480003  116.620003  113.500000  117.440002
# 4  117.010002  114.970001  114.089996  117.330002

# %%
Y.head()
# Out:
# 0    2163600.0
# 1    2386400.0
# 2    2489500.0
# 3    2006300.0
# 4    1408600.0
# Name: volume, dtype: float64

# %%
Y=Y/1000000

# %%
Y.head()
# Out:
# 0    2.1636
# 1    2.3864
# 2    2.4895
# 3    2.0063
# 4    1.4086
# Name: volume, dtype: float64

# %% [markdown]
# ### Divide the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(X,Y,test_size=.30,random_state=2)

# %% [markdown]
# #### Convert Training and Test Data to numpy float32 arrays

# %%
train_x =np.array(train_x).astype('float32')
test_x = np.array(test_x).astype('float32')
train_y =np.array(train_y).astype('float32')
test_y = np.array(test_y).astype('float32')

# %% [markdown]
# ### Normalize the data
# You can use Normalizer from sklearn.preprocessing

# %%
from sklearn.preprocessing import Normalizer

transformer = Normalizer()
train_x = transformer.fit_transform(train_x)
test_x = transformer.transform(test_x)

# %%
train_y.shape
# Out:
# (700,)

# %%
train_y=train_y.reshape(-1,1)

# %%
train_y.shape
# Out:
# (700, 1)

# %% [markdown]
# ## Building the Model in tensorflow

# %% [markdown]
# 1.Define Weights and Bias, use tf.zeros to initialize weights and Bias

# %%
w1 = tf.Variable( tf.random.normal( [4,1] ) )
b1 = tf.Variable( tf.random.normal( [1] ) )

# %%
w1
# Out:
# <tf.Variable 'Variable:0' shape=(4, 1) dtype=float32, numpy=
# array([[-0.18909468],
#        [ 1.3657302 ],
#        [-0.244599  ],
#        [ 1.6396779 ]], dtype=float32)>

# %%
b1
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=float32, numpy=array([-1.0115081], dtype=float32)>

# %% [markdown]
# 2.Define a function to calculate prediction

# %%
def prediction(X_train,W,B):
    out = tf.matmul( X_train,W ) + B
    return out

# %% [markdown]
# 3.Loss (Cost) Function [Mean square error]

# %%
def loss(predicted_y, desired_y):
  return tf.reduce_mean(tf.square(predicted_y - desired_y))

# %% [markdown]
# 4.Function to train the Model
#
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
    
    # Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        t.watch([w,b])
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    # Update Weights and Bias
    w = w - learning_rate * dw
    b = b - learning_rate * db
    
    return w, b

# %% [markdown]
# ## Train the model for 100 epochs
# 1. Observe the training loss at every iteration
# 2. Observe Train loss at every 5th iteration

# %%
for i in range(100):
    i=i+5    
    w1, b1 = train(train_x, train_y, w1, b1)
    print('Current Training Loss on iteration', i, loss(train_y, prediction(train_x, w1, b1)))
# Out:
# ('Current Training Loss on iteration', 5, <tf.Tensor: id=72, shape=(), dtype=float32, numpy=245.11786>)
# ('Current Training Loss on iteration', 6, <tf.Tensor: id=113, shape=(), dtype=float32, numpy=243.03902>)
# ('Current Training Loss on iteration', 7, <tf.Tensor: id=154, shape=(), dtype=float32, numpy=241.12317>)
# ('Current Training Loss on iteration', 8, <tf.Tensor: id=195, shape=(), dtype=float32, numpy=239.35753>)
# ('Current Training Loss on iteration', 9, <tf.Tensor: id=236, shape=(), dtype=float32, numpy=237.73024>)
# ('Current Training Loss on iteration', 10, <tf.Tensor: id=277, shape=(), dtype=float32, numpy=236.23062>)
# ('Current Training Loss on iteration', 11, <tf.Tensor: id=318, shape=(), dtype=float32, numpy=234.84851>)
# ('Current Training Loss on iteration', 12, <tf.Tensor: id=359, shape=(), dtype=float32, numpy=233.5748>)
# ('Current Training Loss on iteration', 13, <tf.Tensor: id=400, shape=(), dtype=float32, numpy=232.4009>)
# ('Current Training Loss on iteration', 14, <tf.Tensor: id=441, shape=(), dtype=float32, numpy=231.31902>)
# ('Current Training Loss on iteration', 15, <tf.Tensor: id=482, shape=(), dtype=float32, numpy=230.32196>)
# ('Current Training Loss on iteration', 16, <tf.Tensor: id=523, shape=(), dtype=float32, numpy=229.4031>)
# ('Current Training Loss on iteration', 17, <tf.Tensor: id=564, shape=(), dtype=float32, numpy=228.55627>)
# ('Current Training Loss on iteration', 18, <tf.Tensor: id=605, shape=(), dtype=float32, numpy=227.77586>)
# ('Current Training Loss on iteration', 19, <tf.Tensor: id=646, shape=(), dtype=float32, numpy=227.05656>)
# ('Current Training Loss on iteration', 20, <tf.Tensor: id=687, shape=(), dtype=float32, numpy=226.3937>)
# ('Current Training Loss on iteration', 21, <tf.Tensor: id=728, shape=(), dtype=float32, numpy=225.7828>)
# ('Current Training Loss on iteration', 22, <tf.Tensor: id=769, shape=(), dtype=float32, numpy=225.21977>)
# ('Current Training Loss on iteration', 23, <tf.Tensor: id=810, shape=(), dtype=float32, numpy=224.70091>)
# ('Current Training Loss on iteration', 24, <tf.Tensor: id=851, shape=(), dtype=float32, numpy=224.22275>)
# ('Current Training Loss on iteration', 25, <tf.Tensor: id=892, shape=(), dtype=float32, numpy=223.78201>)
# ('Current Training Loss on iteration', 26, <tf.Tensor: id=933, shape=(), dtype=float32, numpy=223.37585>)
# ('Current Training Loss on iteration', 27, <tf.Tensor: id=974, shape=(), dtype=float32, numpy=223.00151>)
# ('Current Training Loss on iteration', 28, <tf.Tensor: id=1015, shape=(), dtype=float32, numpy=222.65654>)
# ('Current Training Loss on iteration', 29, <tf.Tensor: id=1056, shape=(), dtype=float32, numpy=222.33864>)
# ('Current Training Loss on iteration', 30, <tf.Tensor: id=1097, shape=(), dtype=float32, numpy=222.04562>)
# ('Current Training Loss on iteration', 31, <tf.Tensor: id=1138, shape=(), dtype=float32, numpy=221.77565>)
# ('Current Training Loss on iteration', 32, <tf.Tensor: id=1179, shape=(), dtype=float32, numpy=221.52675>)
# ('Current Training Loss on iteration', 33, <tf.Tensor: id=1220, shape=(), dtype=float32, numpy=221.2974>)
# ('Current Training Loss on iteration', 34, <tf.Tensor: id=1261, shape=(), dtype=float32, numpy=221.086>)
# ('Current Training Loss on iteration', 35, <tf.Tensor: id=1302, shape=(), dtype=float32, numpy=220.89122>)
# ('Current Training Loss on iteration', 36, <tf.Tensor: id=1343, shape=(), dtype=float32, numpy=220.71165>)
# ('Current Training Loss on iteration', 37, <tf.Tensor: id=1384, shape=(), dtype=float32, numpy=220.54623>)
# ('Current Training Loss on iteration', 38, <tf.Tensor: id=1425, shape=(), dtype=float32, numpy=220.39375>)
# ('Current Training Loss on iteration', 39, <tf.Tensor: id=1466, shape=(), dtype=float32, numpy=220.25323>)
# ('Current Training Loss on iteration', 40, <tf.Tensor: id=1507, shape=(), dtype=float32, numpy=220.12369>)
# ('Current Training Loss on iteration', 41, <tf.Tensor: id=1548, shape=(), dtype=float32, numpy=220.00435>)
# ('Current Training Loss on iteration', 42, <tf.Tensor: id=1589, shape=(), dtype=float32, numpy=219.89433>)
# ('Current Training Loss on iteration', 43, <tf.Tensor: id=1630, shape=(), dtype=float32, numpy=219.79301>)
# ('Current Training Loss on iteration', 44, <tf.Tensor: id=1671, shape=(), dtype=float32, numpy=219.69952>)
# ('Current Training Loss on iteration', 45, <tf.Tensor: id=1712, shape=(), dtype=float32, numpy=219.61339>)
# ('Current Training Loss on iteration', 46, <tf.Tensor: id=1753, shape=(), dtype=float32, numpy=219.53406>)
# ('Current Training Loss on iteration', 47, <tf.Tensor: id=1794, shape=(), dtype=float32, numpy=219.46092>)
# ('Current Training Loss on iteration', 48, <tf.Tensor: id=1835, shape=(), dtype=float32, numpy=219.39352>)
# ('Current Training Loss on iteration', 49, <tf.Tensor: id=1876, shape=(), dtype=float32, numpy=219.33136>)
# ('Current Training Loss on iteration', 50, <tf.Tensor: id=1917, shape=(), dtype=float32, numpy=219.27415>)
# ('Current Training Loss on iteration', 51, <tf.Tensor: id=1958, shape=(), dtype=float32, numpy=219.22139>)
# ('Current Training Loss on iteration', 52, <tf.Tensor: id=1999, shape=(), dtype=float32, numpy=219.17278>)
# ('Current Training Loss on iteration', 53, <tf.Tensor: id=2040, shape=(), dtype=float32, numpy=219.12794>)
# ('Current Training Loss on iteration', 54, <tf.Tensor: id=2081, shape=(), dtype=float32, numpy=219.08665>)
# ('Current Training Loss on iteration', 55, <tf.Tensor: id=2122, shape=(), dtype=float32, numpy=219.0486>)
# ('Current Training Loss on iteration', 56, <tf.Tensor: id=2163, shape=(), dtype=float32, numpy=219.0135>)
# ('Current Training Loss on iteration', 57, <tf.Tensor: id=2204, shape=(), dtype=float32, numpy=218.98114>)
# ('Current Training Loss on iteration', 58, <tf.Tensor: id=2245, shape=(), dtype=float32, numpy=218.95139>)
# ('Current Training Loss on iteration', 59, <tf.Tensor: id=2286, shape=(), dtype=float32, numpy=218.92393>)
# ('Current Training Loss on iteration', 60, <tf.Tensor: id=2327, shape=(), dtype=float32, numpy=218.89859>)
# ('Current Training Loss on iteration', 61, <tf.Tensor: id=2368, shape=(), dtype=float32, numpy=218.87527>)
# ('Current Training Loss on iteration', 62, <tf.Tensor: id=2409, shape=(), dtype=float32, numpy=218.85378>)
# ('Current Training Loss on iteration', 63, <tf.Tensor: id=2450, shape=(), dtype=float32, numpy=218.83392>)
# ('Current Training Loss on iteration', 64, <tf.Tensor: id=2491, shape=(), dtype=float32, numpy=218.81567>)
# ('Current Training Loss on iteration', 65, <tf.Tensor: id=2532, shape=(), dtype=float32, numpy=218.79889>)
# ('Current Training Loss on iteration', 66, <tf.Tensor: id=2573, shape=(), dtype=float32, numpy=218.78337>)
# ('Current Training Loss on iteration', 67, <tf.Tensor: id=2614, shape=(), dtype=float32, numpy=218.76909>)
# ('Current Training Loss on iteration', 68, <tf.Tensor: id=2655, shape=(), dtype=float32, numpy=218.75589>)
# ('Current Training Loss on iteration', 69, <tf.Tensor: id=2696, shape=(), dtype=float32, numpy=218.74374>)
# ('Current Training Loss on iteration', 70, <tf.Tensor: id=2737, shape=(), dtype=float32, numpy=218.73259>)
# ('Current Training Loss on iteration', 71, <tf.Tensor: id=2778, shape=(), dtype=float32, numpy=218.72221>)
# ('Current Training Loss on iteration', 72, <tf.Tensor: id=2819, shape=(), dtype=float32, numpy=218.71274>)
# ('Current Training Loss on iteration', 73, <tf.Tensor: id=2860, shape=(), dtype=float32, numpy=218.704>)
# ('Current Training Loss on iteration', 74, <tf.Tensor: id=2901, shape=(), dtype=float32, numpy=218.6959>)
# ('Current Training Loss on iteration', 75, <tf.Tensor: id=2942, shape=(), dtype=float32, numpy=218.68848>)
# ('Current Training Loss on iteration', 76, <tf.Tensor: id=2983, shape=(), dtype=float32, numpy=218.68158>)
# ('Current Training Loss on iteration', 77, <tf.Tensor: id=3024, shape=(), dtype=float32, numpy=218.67534>)
# ('Current Training Loss on iteration', 78, <tf.Tensor: id=3065, shape=(), dtype=float32, numpy=218.66942>)
# ('Current Training Loss on iteration', 79, <tf.Tensor: id=3106, shape=(), dtype=float32, numpy=218.66408>)
# ('Current Training Loss on iteration', 80, <tf.Tensor: id=3147, shape=(), dtype=float32, numpy=218.65913>)
# ('Current Training Loss on iteration', 81, <tf.Tensor: id=3188, shape=(), dtype=float32, numpy=218.65462>)
# ('Current Training Loss on iteration', 82, <tf.Tensor: id=3229, shape=(), dtype=float32, numpy=218.65036>)
# ('Current Training Loss on iteration', 83, <tf.Tensor: id=3270, shape=(), dtype=float32, numpy=218.6465>)
# ('Current Training Loss on iteration', 84, <tf.Tensor: id=3311, shape=(), dtype=float32, numpy=218.64293>)
# ('Current Training Loss on iteration', 85, <tf.Tensor: id=3352, shape=(), dtype=float32, numpy=218.63966>)
# ('Current Training Loss on iteration', 86, <tf.Tensor: id=3393, shape=(), dtype=float32, numpy=218.63658>)
# ('Current Training Loss on iteration', 87, <tf.Tensor: id=3434, shape=(), dtype=float32, numpy=218.63379>)
# ('Current Training Loss on iteration', 88, <tf.Tensor: id=3475, shape=(), dtype=float32, numpy=218.63121>)
# ('Current Training Loss on iteration', 89, <tf.Tensor: id=3516, shape=(), dtype=float32, numpy=218.62881>)
# ('Current Training Loss on iteration', 90, <tf.Tensor: id=3557, shape=(), dtype=float32, numpy=218.62663>)
# ('Current Training Loss on iteration', 91, <tf.Tensor: id=3598, shape=(), dtype=float32, numpy=218.6246>)
# ('Current Training Loss on iteration', 92, <tf.Tensor: id=3639, shape=(), dtype=float32, numpy=218.62279>)
# ('Current Training Loss on iteration', 93, <tf.Tensor: id=3680, shape=(), dtype=float32, numpy=218.621>)
# ('Current Training Loss on iteration', 94, <tf.Tensor: id=3721, shape=(), dtype=float32, numpy=218.61946>)
# ('Current Training Loss on iteration', 95, <tf.Tensor: id=3762, shape=(), dtype=float32, numpy=218.61804>)
# ('Current Training Loss on iteration', 96, <tf.Tensor: id=3803, shape=(), dtype=float32, numpy=218.61667>)
# ('Current Training Loss on iteration', 97, <tf.Tensor: id=3844, shape=(), dtype=float32, numpy=218.6154>)
# ('Current Training Loss on iteration', 98, <tf.Tensor: id=3885, shape=(), dtype=float32, numpy=218.61424>)
# ('Current Training Loss on iteration', 99, <tf.Tensor: id=3926, shape=(), dtype=float32, numpy=218.61322>)
# ('Current Training Loss on iteration', 100, <tf.Tensor: id=3967, shape=(), dtype=float32, numpy=218.61223>)
# ('Current Training Loss on iteration', 101, <tf.Tensor: id=4008, shape=(), dtype=float32, numpy=218.61134>)
# ('Current Training Loss on iteration', 102, <tf.Tensor: id=4049, shape=(), dtype=float32, numpy=218.61057>)
# ('Current Training Loss on iteration', 103, <tf.Tensor: id=4090, shape=(), dtype=float32, numpy=218.6098>)
# ('Current Training Loss on iteration', 104, <tf.Tensor: id=4131, shape=(), dtype=float32, numpy=218.60902>)

# %% [markdown]
# ### Get the shapes and values of W and b

# %%
w1
# Out:
# <tf.Tensor: id=4120, shape=(4, 1), dtype=float32, numpy=
# array([[1.1111827],
#        [2.7020202],
#        [1.0491397],
#        [2.9822273]], dtype=float32)>

# %%
b1
# Out:
# <tf.Tensor: id=4123, shape=(1,), dtype=float32, numpy=array([1.6253617], dtype=float32)>

# %% [markdown]
# ### Model Prediction on 1st Examples in Test Dataset

# %%
y_pred=prediction(test_x,w1,b1)

# %%
print('Predicted',y_pred[0])
print('Actual',test_y[0])
# Out:
# ('Predicted', <tf.Tensor: id=4138, shape=(1,), dtype=float32, numpy=array([5.564335], dtype=float32)>)
# ('Actual', 0.9716)

# %% [markdown]
# ## Classification using tf.Keras
#
# In this exercise, we will build a Deep Neural Network using tf.Keras. We will use Iris Dataset for this exercise.

# %% [markdown]
# ### Load the given Iris data using pandas (Iris.csv)

# %%
iris = pd.read_csv('/content/drive/My Drive/Great Learning/Residency 6/Day 2/Internal lab/11_Iris.csv')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.set_index('Id',inplace=True)
iris.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Target set has different categories. So, Label encode them. And convert into one-hot vectors using get_dummies in pandas.

# %%
iris_encode=pd.get_dummies(iris, drop_first=False)
iris_encode.head()
# Out:
#     SepalLengthCm  ...  Species_Iris-virginica
# Id                 ...
# 1             5.1  ...                       0
# 2             4.9  ...                       0
# 3             4.7  ...                       0
# 4             4.6  ...                       0
# 5             5.0  ...                       0
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Splitting the data into feature set and target set

# %%
x = iris_encode.iloc[:,:4]
y = iris_encode.iloc[:,4:7]

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
print(x.head())
print(x.shape)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1             5.1           3.5            1.4           0.2
# 2             4.9           3.0            1.4           0.2
# 3             4.7           3.2            1.3           0.2
# 4             4.6           3.1            1.5           0.2
# 5             5.0           3.6            1.4           0.2
# (150, 4)

# %%
print(y.head())
print(y.shape)
# Out:
#     Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# Id
# 1                     1                        0                       0
# 2                     1                        0                       0
# 3                     1                        0                       0
# 4                     1                        0                       0
# 5                     1                        0                       0
# (150, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ###  Building Model in tf.keras
#
# Build a Linear Classifier model  <br>
# 1.  Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3<br>
# 2. Apply Softmax on Dense Layer outputs <br>
# 3. Use SGD as Optimizer
# 4. Use categorical_crossentropy as loss function

# %%
# baseline model
def create_baseline():
    # create model
  model = Sequential()
  model.add(Dense(10, input_shape=(4,), activation='softmax', name='fc1'))
  #model.add(Dense(10, activation='softmax', name='fc2'))
  model.add(Dense(3, activation='softmax', name='output'))
  model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
  # baseline model
def hiddenlayer_2():
    # create model
  model = Sequential()
  model.add(Dense(10, input_shape=(4,), activation='softmax', name='fc1'))
  model.add(Dense(3, activation='softmax', name='fc2'))
  model.add(Dense(3, activation='softmax', name='output'))
  model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### Model Training

# %%
model = create_baseline()
print('Neural Network Model Summary: ')
print(model.summary())
# Train the model

model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                50
# _________________________________________________________________
# output (Dense)               (None, 3)                 33
# =================================================================
# Total params: 83
# Trainable params: 83
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <type 'NoneType'>
# Train on 120 samples
# Epoch 1/200
# 120/120 - 0s - loss: 1.2205 - accuracy: 0.3417
# Epoch 2/200
# 120/120 - 0s - loss: 1.1927 - accuracy: 0.3417
# Epoch 3/200
# 120/120 - 0s - loss: 1.1725 - accuracy: 0.3417
# Epoch 4/200
# 120/120 - 0s - loss: 1.1564 - accuracy: 0.3417
# Epoch 5/200
# 120/120 - 0s - loss: 1.1441 - accuracy: 0.3417
# Epoch 6/200
# 120/120 - 0s - loss: 1.1351 - accuracy: 0.3417
# Epoch 7/200
# 120/120 - 0s - loss: 1.1276 - accuracy: 0.3417
# Epoch 8/200
# 120/120 - 0s - loss: 1.1223 - accuracy: 0.3417
# Epoch 9/200
# 120/120 - 0s - loss: 1.1179 - accuracy: 0.3417
# Epoch 10/200
# 120/120 - 0s - loss: 1.1143 - accuracy: 0.3417
# Epoch 11/200
# 120/120 - 0s - loss: 1.1116 - accuracy: 0.3417
# Epoch 12/200
# 120/120 - 0s - loss: 1.1096 - accuracy: 0.3417
# Epoch 13/200
200
# 120/120 - 0s - loss: 1.0995 - accuracy: 0.3417

# %% [markdown]
# ### Model Prediction

# %%
results = model.evaluate(test_x, test_y)
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <type 'NoneType'>
# 30/30 [==============================] - 0s 617us/sample - loss: 1.1009 - accuracy: 0.3000
# Final test set loss: 1.100853
# Final test set accuracy: 0.300000

# %% [markdown]
# ### Save the Model

# %%
model.save('R6_Iris_NN.ipynb')
# Out:
# WARNING:tensorflow:From /tensorflow-2.0.0/python2.7/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling __init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: R6_Iris_NN.ipynb/assets
# INFO:tensorflow:Assets written to: assets

# %% [markdown]
# ### Build and Train a Deep Neural network with 2 hidden layer  - Optional - For Practice
#
# Does it perform better than Linear Classifier? What could be the reason for difference in performance?

# %%
model = hiddenlayer_2()
print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
results = model.evaluate(test_x, test_y)
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Neural Network Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                50
# _________________________________________________________________
# fc2 (Dense)                  (None, 3)                 33
# _________________________________________________________________
# output (Dense)               (None, 3)                 12
# =================================================================
# Total params: 95
# Trainable params: 95
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <type 'NoneType'>
# Train on 120 samples
# Epoch 1/200
# 120/120 - 0s - loss: 1.1386 - accuracy: 0.3417
# Epoch 2/200
# 120/120 - 0s - loss: 1.1299 - accuracy: 0.3417
# Epoch 3/200
# 120/120 - 0s - loss: 1.1230 - accuracy: 0.3417
# Epoch 4/200
# 120/120 - 0s - loss: 1.1174 - accuracy: 0.3417
# Epoch 5/200
# 120/120 - 0s - loss: 1.1133 - accuracy: 0.3417
# Epoch 6/200
# 120/120 - 0s - loss: 1.1097 - accuracy: 0.3417
# Epoch 7/200
# 120/120 - 0s - loss: 1.1071 - accuracy: 0.3417
# Epoch 8/200
# 120/120 - 0s - loss: 1.1052 - accuracy: 0.3417
# Epoch 9/200
# 120/120 - 0s - loss: 1.1036 - accuracy: 0.3417
# Epoch 10/200
# 120/120 - 0s - loss: 1.1023 - accuracy: 0.3417
# Epoch 11/200
# 120/120 - 0s - loss: 1.1013 - accuracy: 0.3417
# Epoch 12/200
# 120/120 - 0s - loss: 1.1008 - accuracy: 0.3417
# Epoch 13/200
# 120/120 - 0s - loss: 1.0995 - accuracy: 0.3417
# Epoch 14/200
# 120/120 - 0s - loss: 1.0992 - accuracy: 0.3417
# Epoch 15/200
# 120/120 - 0s - loss: 1.0992 - accuracy: 0.3417
# Epoch 16/200
# 120/120 - 0s - loss: 1.0988 - accuracy: 0.3417
# Epoch 17/200
# 120/120 - 0s - loss: 1.0983 - accuracy: 0.3417
# Epoch 18/200
# 120/120 - 0s - loss: 1.0977 - accuracy: 0.3417
# Epoch 19/200
# 120/120 - 0s - loss: 1.0977 - accuracy: 0.3417
# Epoch 20/200
# 120/120 - 0s - loss: 1.0975 - accuracy: 0.3417
# Epoch 21/200
# 120/120 - 0s - loss: 1.0972 - accuracy: 0.3417
# Epoch 22/200
# 120/120 - 0s - loss: 1.0970 - accuracy: 0.3417
# Epoch 23/200
# 120/120 - 0s - loss: 1.0970 - accuracy: 0.3417
# Epoch 24/200
# 120/120 - 0s - loss: 1.0969 - accuracy: 0.3417
# Epoch 25/200
# 120/120 - 0s - loss: 1.0968 - accuracy: 0.3417
# Epoch 26/200
# 120/120 - 0s - loss: 1.0965 - accuracy: 0.3417
# Epoch 27/200
# 120/120 - 0s - loss: 1.0966 - accuracy: 0.3417
# Epoch 28/200
# 120/120 - 0s - loss: 1.0963 - accuracy: 0.3417
# Epoch 29/200
# 120/120 - 0s - loss: 1.0966 - accuracy: 0.3417
# Epoch 30/200
# 120/120 - 0s - loss: 1.0961 - accuracy: 0.3417
# Epoch 31/200
# 120/120 - 0s - loss: 1.0958 - accuracy: 0.3417
# Epoch 32/200
# 120/120 - 0s - loss: 1.0959 - accuracy: 0.3417
# Epoch 33/200
# 120/120 - 0s - loss: 1.0959 - accuracy: 0.3500
# Epoch 34/200
# 120/120 - 0s - loss: 1.0957 - accuracy: 0.3500
# Epoch 35/200
# 120/120 - 0s - loss: 1.0955 - accuracy: 0.4417
# Epoch 36/200
# 120/120 - 0s - loss: 1.0955 - accuracy: 0.3583
# Epoch 37/200
# 120/120 - 0s - loss: 1.0952 - accuracy: 0.3500
# Epoch 38/200
# 120/120 - 0s - loss: 1.0950 - accuracy: 0.3500
# Epoch 39/200
# 120/120 - 0s - loss: 1.0950 - accuracy: 0.3667
# Epoch 40/200
# 120/120 - 0s - loss: 1.0950 - accuracy: 0.3583
# Epoch 41/200
# 120/120 - 0s - loss: 1.0943 - accuracy: 0.3833
# Epoch 42/200
# 120/120 - 0s - loss: 1.0944 - accuracy: 0.4250
# Epoch 43/200
# 120/120 - 0s - loss: 1.0942 - accuracy: 0.3750
# Epoch 44/200
# 120/120 - 0s - loss: 1.0943 - accuracy: 0.4083
# Epoch 45/200
# 120/120 - 0s - loss: 1.0937 - accuracy: 0.3750
# Epoch 46/200
# 120/120 - 0s - loss: 1.0938 - accuracy: 0.3750
# Epoch 47/200
# 120/120 - 0s - loss: 1.0936 - accuracy: 0.3833
# Epoch 48/200
# 120/120 - 0s - loss: 1.0932 - accuracy: 0.3667
# Epoch 49/200
# 120/120 - 0s - loss: 1.0932 - accuracy: 0.3667
# Epoch 50/200
# 120/120 - 0s - loss: 1.0930 - accuracy: 0.3583
# Epoch 51/200
# 120/120 - 0s - loss: 1.0927 - accuracy: 0.3750
# Epoch 52/200
# 120/120 - 0s - loss: 1.0924 - accuracy: 0.3917
# Epoch 53/200
# 120/120 - 0s - loss: 1.0924 - accuracy: 0.3583
# Epoch 54/200
# 120/120 - 0s - loss: 1.0920 - accuracy: 0.4417
# Epoch 55/200
# 120/120 - 0s - loss: 1.0917 - accuracy: 0.3917
# Epoch 56/200
# 120/120 - 0s - loss: 1.0911 - accuracy: 0.4250
# Epoch 57/200
# 120/120 - 0s - loss: 1.0912 - accuracy: 0.4000
# Epoch 58/200
# 120/120 - 0s - loss: 1.0908 - accuracy: 0.4333
# Epoch 59/200
# 120/120 - 0s - loss: 1.0905 - accuracy: 0.4083
# Epoch 60/200
# 120/120 - 0s - loss: 1.0901 - accuracy: 0.3583
# Epoch 61/200
# 120/120 - 0s - loss: 1.0900 - accuracy: 0.4500
# Epoch 62/200
# 120/120 - 0s - loss: 1.0894 - accuracy: 0.3917
# Epoch 63/200
# 120/120 - 0s - loss: 1.0892 - accuracy: 0.4417
# Epoch 64/200
# 120/120 - 0s - loss: 1.0889 - accuracy: 0.4083
# Epoch 65/200
# 120/120 - 0s - loss: 1.0883 - accuracy: 0.4000
# Epoch 66/200
# 120/120 - 0s - loss: 1.0878 - accuracy: 0.4417
# Epoch 67/200
# 120/120 - 0s - loss: 1.0879 - accuracy: 0.3917
# Epoch 68/200
# 120/120 - 0s - loss: 1.0876 - accuracy: 0.4000
# Epoch 69/200
# 120/120 - 0s - loss: 1.0867 - accuracy: 0.4500
# Epoch 70/200
# 120/120 - 0s - loss: 1.0863 - accuracy: 0.4583
# Epoch 71/200
# 120/120 - 0s - loss: 1.0861 - accuracy: 0.4250
# Epoch 72/200
# 120/120 - 0s - loss: 1.0855 - accuracy: 0.4333
# Epoch 73/200
# 120/120 - 0s - loss: 1.0851 - accuracy: 0.4250
# Epoch 74/200
# 120/120 - 0s - loss: 1.0848 - accuracy: 0.4833
# Epoch 75/200
# 120/120 - 0s - loss: 1.0839 - accuracy: 0.4417
# Epoch 76/200
# 120/120 - 0s - loss: 1.0837 - accuracy: 0.4000
# Epoch 77/200
# 120/120 - 0s - loss: 1.0829 - accuracy: 0.4250
# Epoch 78/200
# 120/120 - 0s - loss: 1.0825 - accuracy: 0.5000
# Epoch 79/200
# 120/120 - 0s - loss: 1.0820 - accuracy: 0.4917
# Epoch 80/200
# 120/120 - 0s - loss: 1.0811 - accuracy: 0.4083
# Epoch 81/200
# 120/120 - 0s - loss: 1.0804 - accuracy: 0.3833
# Epoch 82/200
# 120/120 - 0s - loss: 1.0795 - accuracy: 0.4583
# Epoch 83/200
# 120/120 - 0s - loss: 1.0788 - accuracy: 0.4417
# Epoch 84/200
# 120/120 - 0s - loss: 1.0778 - accuracy: 0.4750
# Epoch 85/200
# 120/120 - 0s - loss: 1.0770 - accuracy: 0.4250
# Epoch 86/200
# 120/120 - 0s - loss: 1.0763 - accuracy: 0.4417
# Epoch 87/200
# 120/120 - 0s - loss: 1.0751 - accuracy: 0.5000
# Epoch 88/200
# 120/120 - 0s - loss: 1.0741 - accuracy: 0.4500
# Epoch 89/200
# 120/120 - 0s - loss: 1.0732 - accuracy: 0.5167
# Epoch 90/200
# 120/120 - 0s - loss: 1.0718 - accuracy: 0.4500
# Epoch 91/200
# 120/120 - 0s - loss: 1.0704 - accuracy: 0.5000
# Epoch 92/200
# 120/120 - 0s - loss: 1.0693 - accuracy: 0.5083
# Epoch 93/200
# 120/120 - 0s - loss: 1.0678 - accuracy: 0.4750
# Epoch 94/200
# 120/120 - 0s - loss: 1.0662 - accuracy: 0.4417
# Epoch 95/200
# 120/120 - 0s - loss: 1.0644 - accuracy: 0.4667
# Epoch 96/200
# 120/120 - 0s - loss: 1.0628 - accuracy: 0.4917
# Epoch 97/200
# 120/120 - 0s - loss: 1.0612 - accuracy: 0.4250
# Epoch 98/200
# 120/120 - 0s - loss: 1.0600 - accuracy: 0.4750
# Epoch 99/200
# 120/120 - 0s - loss: 1.0570 - accuracy: 0.5000
# Epoch 100/200
# 120/120 - 0s - loss: 1.0548 - accuracy: 0.4250
# Epoch 101/200
# 120/120 - 0s - loss: 1.0530 - accuracy: 0.4583
# Epoch 102/200
# 120/120 - 0s - loss: 1.0502 - accuracy: 0.4667
# Epoch 103/200
# 120/120 - 0s - loss: 1.0482 - accuracy: 0.4167
# Epoch 104/200
# 120/120 - 0s - loss: 1.0452 - accuracy: 0.4917
# Epoch 105/200
# 120/120 - 0s - loss: 1.0424 - accuracy: 0.4500
# Epoch 106/200
# 120/120 - 0s - loss: 1.0393 - accuracy: 0.4750
# Epoch 107/200
# 120/120 - 0s - loss: 1.0362 - accuracy: 0.4583
# Epoch 108/200
# 120/120 - 0s - loss: 1.0331 - accuracy: 0.6000
# Epoch 109/200
# 120/120 - 0s - loss: 1.0294 - accuracy: 0.7000
# Epoch 110/200
# 120/120 - 0s - loss: 1.0259 - accuracy: 0.7750
# Epoch 111/200
# 120/120 - 0s - loss: 1.0217 - accuracy: 0.8000
# Epoch 112/200
# 120/120 - 0s - loss: 1.0181 - accuracy: 0.8167
# Epoch 113/200
# 120/120 - 0s - loss: 1.0141 - accuracy: 0.7000
# Epoch 114/200
# 120/120 - 0s - loss: 1.0097 - accuracy: 0.7417
# Epoch 115/200
# 120/120 - 0s - loss: 1.0051 - accuracy: 0.7833
# Epoch 116/200
# 120/120 - 0s - loss: 1.0002 - accuracy: 0.7583
# Epoch 117/200
# 120/120 - 0s - loss: 0.9960 - accuracy: 0.7417
# Epoch 118/200
# 120/120 - 0s - loss: 0.9911 - accuracy: 0.7750
# Epoch 119/200
# 120/120 - 0s - loss: 0.9865 - accuracy: 0.7583
# Epoch 120/200
# 120/120 - 0s - loss: 0.9811 - accuracy: 0.7250
# Epoch 121/200
# 120/120 - 0s - loss: 0.9765 - accuracy: 0.6917
# Epoch 122/200
# 120/120 - 0s - loss: 0.9708 - accuracy: 0.7417
# Epoch 123/200
# 120/120 - 0s - loss: 0.9651 - accuracy: 0.7250
# Epoch 124/200
# 120/120 - 0s - loss: 0.9594 - accuracy: 0.7083
# Epoch 125/200
# 120/120 - 0s - loss: 0.9541 - accuracy: 0.7500
# Epoch 126/200
# 120/120 - 0s - loss: 0.9481 - accuracy: 0.7167
# Epoch 127/200
# 120/120 - 0s - loss: 0.9420 - accuracy: 0.7083
# Epoch 128/200
# 120/120 - 0s - loss: 0.9361 - accuracy: 0.7083
# Epoch 129/200
# 120/120 - 0s - loss: 0.9303 - accuracy: 0.6917
# Epoch 130/200
# 120/120 - 0s - loss: 0.9243 - accuracy: 0.7250
# Epoch 131/200
# 120/120 - 0s - loss: 0.9183 - accuracy: 0.7333
# Epoch 132/200
# 120/120 - 0s - loss: 0.9119 - accuracy: 0.7000
# Epoch 133/200
# 120/120 - 0s - loss: 0.9056 - accuracy: 0.7250
# Epoch 134/200
# 120/120 - 0s - loss: 0.8996 - accuracy: 0.7333
# Epoch 135/200
# 120/120 - 0s - loss: 0.8931 - accuracy: 0.7250
# Epoch 136/200
# 120/120 - 0s - loss: 0.8869 - accuracy: 0.7083
# Epoch 137/200
# 120/120 - 0s - loss: 0.8805 - accuracy: 0.7000
# Epoch 138/200
# 120/120 - 0s - loss: 0.8737 - accuracy: 0.6833
# Epoch 139/200
# 120/120 - 0s - loss: 0.8675 - accuracy: 0.6917
# Epoch 140/200
# 120/120 - 0s - loss: 0.8614 - accuracy: 0.7500
# Epoch 141/200
# 120/120 - 0s - loss: 0.8547 - accuracy: 0.6833
# Epoch 142/200
# 120/120 - 0s - loss: 0.8485 - accuracy: 0.7167
# Epoch 143/200
# 120/120 - 0s - loss: 0.8420 - accuracy: 0.6917
# Epoch 144/200
# 120/120 - 0s - loss: 0.8355 - accuracy: 0.7000
# Epoch 145/200
# 120/120 - 0s - loss: 0.8295 - accuracy: 0.7083
# Epoch 146/200
# 120/120 - 0s - loss: 0.8231 - accuracy: 0.6917
# Epoch 147/200
# 120/120 - 0s - loss: 0.8170 - accuracy: 0.7000
# Epoch 148/200
# 120/120 - 0s - loss: 0.8108 - accuracy: 0.7083
# Epoch 149/200
# 120/120 - 0s - loss: 0.8046 - accuracy: 0.7000
# Epoch 150/200
# 120/120 - 0s - loss: 0.7988 - accuracy: 0.6917
# Epoch 151/200
# 120/120 - 0s - loss: 0.7926 - accuracy: 0.6917
# Epoch 152/200
# 120/120 - 0s - loss: 0.7866 - accuracy: 0.7000
# Epoch 153/200
# 120/120 - 0s - loss: 0.7806 - accuracy: 0.7000
# Epoch 154/200
# 120/120 - 0s - loss: 0.7748 - accuracy: 0.7000
# Epoch 155/200
# 120/120 - 0s - loss: 0.7689 - accuracy: 0.7000
# Epoch 156/200
# 120/120 - 0s - loss: 0.7637 - accuracy: 0.7000
# Epoch 157/200
# 120/120 - 0s - loss: 0.7579 - accuracy: 0.7000
# Epoch 158/200
# 120/120 - 0s - loss: 0.7522 - accuracy: 0.7000
# Epoch 159/200
# 120/120 - 0s - loss: 0.7468 - accuracy: 0.7000
# Epoch 160/200
# 120/120 - 0s - loss: 0.7414 - accuracy: 0.7000
# Epoch 161/200
# 120/120 - 0s - loss: 0.7361 - accuracy: 0.7000
# Epoch 162/200
# 120/120 - 0s - loss: 0.7310 - accuracy: 0.7000
# Epoch 163/200
# 120/120 - 0s - loss: 0.7259 - accuracy: 0.7000
# Epoch 164/200
# 120/120 - 0s - loss: 0.7207 - accuracy: 0.7083
# Epoch 165/200
# 120/120 - 0s - loss: 0.7159 - accuracy: 0.7083
# Epoch 166/200
# 120/120 - 0s - loss: 0.7111 - accuracy: 0.7000
# Epoch 167/200
# 120/120 - 0s - loss: 0.7064 - accuracy: 0.7000
# Epoch 168/200
# 120/120 - 0s - loss: 0.7016 - accuracy: 0.7083
# Epoch 169/200
# 120/120 - 0s - loss: 0.6972 - accuracy: 0.7083
# Epoch 170/200
# 120/120 - 0s - loss: 0.6925 - accuracy: 0.7083
# Epoch 171/200
# 120/120 - 0s - loss: 0.6882 - accuracy: 0.7167
# Epoch 172/200
# 120/120 - 0s - loss: 0.6840 - accuracy: 0.7167
# Epoch 173/200
# 120/120 - 0s - loss: 0.6797 - accuracy: 0.7083
# Epoch 174/200
# 120/120 - 0s - loss: 0.6756 - accuracy: 0.7083
# Epoch 175/200
# 120/120 - 0s - loss: 0.6716 - accuracy: 0.7083
# Epoch 176/200
# 120/120 - 0s - loss: 0.6678 - accuracy: 0.7167
# Epoch 177/200
# 120/120 - 0s - loss: 0.6638 - accuracy: 0.7167
# Epoch 178/200
# 120/120 - 0s - loss: 0.6602 - accuracy: 0.7083
# Epoch 179/200
# 120/120 - 0s - loss: 0.6564 - accuracy: 0.7083
# Epoch 180/200
# 120/120 - 0s - loss: 0.6530 - accuracy: 0.7167
# Epoch 181/200
# 120/120 - 0s - loss: 0.6495 - accuracy: 0.7083
# Epoch 182/200
# 120/120 - 0s - loss: 0.6461 - accuracy: 0.7167
# Epoch 183/200
# 120/120 - 0s - loss: 0.6428 - accuracy: 0.7167
# Epoch 184/200
# 120/120 - 0s - loss: 0.6395 - accuracy: 0.7083
# Epoch 185/200
# 120/120 - 0s - loss: 0.6363 - accuracy: 0.7250
# Epoch 186/200
# 120/120 - 0s - loss: 0.6331 - accuracy: 0.7083
# Epoch 187/200
# 120/120 - 0s - loss: 0.6298 - accuracy: 0.7167
# Epoch 188/200
# 120/120 - 0s - loss: 0.6274 - accuracy: 0.7083
# Epoch 189/200
# 120/120 - 0s - loss: 0.6242 - accuracy: 0.7083
# Epoch 190/200
# 120/120 - 0s - loss: 0.6214 - accuracy: 0.7167
# Epoch 191/200
# 120/120 - 0s - loss: 0.6187 - accuracy: 0.7167
# Epoch 192/200
# 120/120 - 0s - loss: 0.6162 - accuracy: 0.7167
# Epoch 193/200
# 120/120 - 0s - loss: 0.6134 - accuracy: 0.7167
# Epoch 194/200
# 120/120 - 0s - loss: 0.6107 - accuracy: 0.7167
# Epoch 195/200
# 120/120 - 0s - loss: 0.6082 - accuracy: 0.7167
# Epoch 196/200
# 120/120 - 0s - loss: 0.6059 - accuracy: 0.7167
# Epoch 197/200
# 120/120 - 0s - loss: 0.6035 - accuracy: 0.7083
# Epoch 198/200
# 120/120 - 0s - loss: 0.6011 - accuracy: 0.7167
# Epoch 199/200
# 120/120 - 0s - loss: 0.5989 - accuracy: 0.7083
# Epoch 200/200
# 120/120 - 0s - loss: 0.5967 - accuracy: 0.7167
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <type 'NoneType'>
# 30/30 [==============================] - 0s 648us/sample - loss: 0.5741 - accuracy: 0.7333
# Final test set loss: 0.574098
# Final test set accuracy: 0.733333
